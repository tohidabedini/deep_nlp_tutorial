# %% [markdown]
# # Best practices for NLP

# %% [markdown]
# Create word vectors after preprocessing our NL data

# %% [markdown]
# #### Load Dependencies

# %%
import nltk
from nltk import word_tokenize, sent_tokenize
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show,figure
# %matplotlib inline
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tohid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords
from nltk.stem.porter import *
from gensim.models.phrases import Phraser,Phrases
from keras.preprocessing.text import one_hot

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tohid\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# #### Load data

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Tohid\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg

# %%
gberg_sents = gutenberg.sents()

# %% [markdown]
# #### Preprocess a sentence

# %%
gberg_sents[4]
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %% [markdown]
# #### to lowercase

# %%
[w.lower() for w in gberg_sents[4]]
# Out:
# ['she',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %% [markdown]
# #### remove stopwords and punctuation:

# %%
stpwords = stopwords.words('english') + list(string.punctuation)

# %%
stpwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
[w.lower() for w in gberg_sents[4] if w not in stpwords]
# Out:
# ['she',
#  'youngest',
#  'two',
#  'daughters',
#  'affectionate',
#  'indulgent',
#  'father',
#  'consequence',
#  'sister',
#  'marriage',
#  'mistress',
#  'house',
#  'early',
#  'period']

# %% [markdown]
# #### stem words:

# %%
stemmer = PorterStemmer()

# %%
[stemmer.stem(w.lower()) for w in gberg_sents[4] if w not in stpwords]
# Out:
# ['she',
#  'youngest',
#  'two',
#  'daughter',
#  'affection',
#  'indulg',
#  'father',
#  'consequ',
#  'sister',
#  'marriag',
#  'mistress',
#  'hous',
#  'earli',
#  'period']

# %% [markdown]
# ##### in large corpus we may not stem our words

# %% [markdown]
# #### handle bigram collocation

# %%
phrases = Phrases(gberg_sents)

# %%
bigram = Phraser(phrases)

# %%
bigram.phrasegrams
# Out:
# {(b'these', b'songs'): (15, 21.653396358543414),
#  (b'Moses', b'commanded'): (16, 16.28623722743074),
#  (b'"', b'Dear'): (39, 20.048661090579007),
#  (b'bear', b'witness'): (15, 75.90968232925812),
#  (b'protest', b'against'): (6, 10.157197996222385),
#  (b'peace', b'offerings'): (83, 305.3930864197531),
#  (b'New', b'Bedford'): (18, 4097.590723751274),
#  (b'hath', b'wrought'): (15, 18.88619802959877),
#  (b'136', b':'): (26, 10.14627074866285),
#  (b'reared', b'up'): (11, 44.04969430759186),
#  (b'youngest', b'brother'): (6, 19.580198834853086),
#  (b'talking', b'about'): (24, 19.191191650605955),
#  (b'surely', b'live'): (9, 16.90506259909245),
#  (b'm', b'glad'): (20, 54.476832276250875),
#  (b'own', b'selves'): (7, 42.89526253728237),
#  (b'must', b'be'): (601, 10.229989650632808),
#  (b'come', b'hither'): (17, 16.82244185519336),
#  (b'communed', b'with'): (17, 22.051025138170797),
#  (b'reference', b'to'): (30, 10.087650616363232),
# ...

# %%
"Jon lives in New York City".split()
# Out:
# ['Jon', 'lives', 'in', 'New', 'York', 'City']

# %%
bigram["Jon lives in New York City".split()]
# Out:
# ['Jon', 'lives', 'in', 'New_York', 'City']

# %% [markdown]
# #### Preprocess the corpus

# %%
lower_sents =[]
for s in gberg_sents:
    lower_sents.append([w.lower() for w in s if w not in list(string.punctuation)])

# %%
lower_sents[0]
# Out:
# ['emma', 'by', 'jane', 'austen', '1816']

# %%
lower_bigram = Phraser(Phrases(lower_sents))

# %%
lower_bigram.phrasegrams
# Out:
# {(b'dwell', b'therein'): (37, 189.42088991507845),
#  (b'these', b'songs'): (15, 15.495812524010757),
#  (b'bear', b'witness'): (15, 51.98824530198747),
#  (b'very', b'agreeable'): (21, 20.122524320279375),
#  (b'peace', b'offerings'): (83, 269.5706305050667),
#  (b'live', b'saith'): (21, 13.942562176300129),
#  (b'hath', b'wrought'): (15, 17.67942143326759),
#  (b'tinder', b'box'): (8, 1207.6526946107783),
#  (b'moses', b'spake'): (18, 13.877318343495933),
#  (b'mount', b'sinai'): (19, 654.191844300278),
#  (b'reared', b'up'): (11, 38.03770026300072),
#  (b'youngest', b'brother'): (6, 17.85077004779607),
#  (b'talking', b'about'): (25, 19.032959773504775),
#  (b'surely', b'live'): (9, 11.35297318597189),
#  (b'm', b'glad'): (20, 46.73761458440622),
#  (b'driven', b'away'): (10, 13.8188620292715),
#  (b'book', b'ii'): (9, 139.66620498614958),
#  (b'captain', b'peleg'): (32, 234.78230500582075),
#  (b'own', b'selves'): (7, 41.910019741627124),
# ...

# %%
lower_bigram.phrasegrams[b'on', b'purpose'][0]
# Out:
# 36

# %%
lower_bigram["jon lives in new york city".split()]
# Out:
# ['jon', 'lives', 'in', 'new_york', 'city']

# %%
lower_bigram = Phraser(Phrases(lower_sents, min_count=32,threshold=64))

# %%
lower_bigram.phrasegrams
# Out:
# {(b'afar', b'off'): (52, 108.14220347465505),
#  (b'burnt', b'offering'): (184, 297.524653753951),
#  (b'burnt', b'offerings'): (86, 299.15702343127646),
#  (b'buster', b'bear'): (142, 479.87410772225826),
#  (b'captain', b'benwick'): (56, 241.49037086312987),
#  (b'captain', b'wentworth'): (196, 529.8756608388247),
#  (b'charles', b'hayter'): (33, 92.03437785214481),
#  (b'chief', b'priests'): (65, 116.31947753846512),
#  (b'colonel', b'brandon'): (132, 1313.0078125),
#  (b'couldn', b't'): (89, 171.76138536935215),
#  (b'cut', b'off'): (217, 129.60290535032792),
#  (b'dare', b'say'): (115, 89.94000515807346),
#  (b'de', b'grey'): (77, 603.2109624246722),
#  (b'didn', b't'): (180, 220.51081560283686),
#  (b'doesn', b't'): (53, 106.2634985949418),
#  (b'don', b't'): (830, 250.30957446808512),
#  (b'dr', b'bull'): (65, 680.7870294599019),
#  (b'dr', b'middleton'): (40, 162.73103819257668),
#  (b'drawing', b'room'): (49, 84.91494947493561),
# ...

# %% [markdown]
# #### it is on your own to leave stem and stopwords

# %%
clean_sents=[]
for s in lower_sents:
    clean_sents.append(lower_bigram[s])

# %%
# clean_sents[0:10]

# %% [markdown]
# #### Run word2vec

# %%
model = Word2Vec(sentences=clean_sents, size=64, sg=1, window=10, min_count=10, seed=42, workers=2)
model.save('clean_gutenberg_model.w2v')
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
model = gensim.models.Word2Vec.load("clean_gutenberg_model.w2v")
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
len(model.wv.vocab)
# Out:
# 10329

# %% [markdown]
# #### Explore model

# %%
model["ma_am"]
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.1317667 , -0.73403615,  0.28600484,  0.25189152, -0.3456874 ,
#         0.03227838, -0.68413025,  0.01403036, -0.35089758, -0.15893832,
#         0.10722354, -0.05922178, -0.13912393, -0.28833917,  0.30561122,
#        -0.565235  ,  0.4752804 , -0.14712274,  0.02576193, -0.1374264 ,
#         0.1915584 ,  0.02077205, -0.10517322,  0.25685412,  0.4451153 ,
#         0.4481551 , -0.5382011 ,  0.20357797, -0.5151954 ,  0.3720144 ,
#        -0.37671193,  0.27184016,  0.29493633,  0.5123045 ,  0.6508016 ,
#        -0.05339734, -0.09975969, -0.36431062,  0.10987179, -0.07361302,
#         0.04864489, -0.09081707, -0.47183535,  0.37602407, -0.02620832,
#        -0.19004579, -0.0776467 ,  0.2562778 , -0.45277196,  0.48885298,
# ...

# %%
model.most_similar(positive=['ma_am','man'],negative=['woman'])
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('todhunter', 0.7515734434127808),
#  ('anyhow', 0.7472516894340515),
#  ("'--", 0.7438434958457947),
#  ('wilkinson', 0.7402777671813965),
#  ('grimly', 0.7386406064033508),
#  ('dr', 0.7345077395439148),
#  ('policeman', 0.7261126041412354),
#  ('but', 0.7245124578475952),
#  ('hatter', 0.7224700450897217),
#  ('impatiently', 0.7209322452545166)]

# %%
model.most_similar(positive=['father','woman'],negative=['man'])
# Out:
# E:\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('husband', 0.7923126220703125),
#  ('mother', 0.7709376811981201),
#  ('wife', 0.7576456069946289),
#  ('sister', 0.7437680959701538),
#  ('daughter', 0.737549364566803),
#  ('child', 0.6840465068817139),
#  ('sarai', 0.6716598272323608),
#  ('sarah', 0.6709963083267212),
#  ('youngest', 0.6684953570365906),
#  ('womb', 0.665264368057251)]

# %% [markdown]
# #### Reduce dimensionality

# %%
coords_df=pd.read_csv('clean_gutenberg_tsne.csv')

# %%
_ = coords_df.plot.scatter('x','y',figsize=(8,8),marker='.',s=10,alpha=0.2)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b7a75415-337a-4d53-9598-4e283a4bd1a5">Loading BokehJS ...</span>
#     </div>

# %%
subset_df=coords_df.sample(n=5000)

# %%
p = figure(plot_width=600,plot_height=600)
_ = p.text(x=subset_df.x,y=subset_df.y,text=subset_df.token)

# %%
show(p)
# Out:
#   <div class="bk-root" id="c34f5058-c6c9-4073-a8d3-85e4197c6387"></div>
